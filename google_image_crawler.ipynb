# %%
from icrawler.builtin import GoogleImageCrawler

# %%
# GoogleImageCrawler 객체 생성
google_crawler = GoogleImageCrawler(storage={'root_dir': './images'})
google_crawler.crawl(keyword='pigeon', max_num=50)
# Out:
# 2021-01-27 22:36:20,987 - INFO - icrawler.crawler - start crawling...
# 2021-01-27 22:36:20,988 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-01-27 22:36:20,989 - INFO - feeder - thread feeder-001 exit
# 2021-01-27 22:36:20,991 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-01-27 22:36:20,992 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-01-27 22:36:22,056 - INFO - parser - parsing result page https://www.google.com/search?q=pigeon&ijn=0&start=0&tbs=&tbm=isch
# 2021-01-27 22:36:22,746 - ERROR - downloader - Response status code 404, file https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Domestic-pigeon.jpg
# 2021-01-27 22:36:24,636 - INFO - downloader - image #1	https://nas-national-prod.s3.amazonaws.com/styles/hero_image/s3/_web_apa_2016_rock-pigeon_laura_perrotta_kk.jpg
# 2021-01-27 22:36:24,772 - INFO - downloader - image #2	https://ichef.bbci.co.uk/news/1024/cpsprodpb/49F6/production/_97643981_pigeon_1.jpg
# ...

# %%
# GoogleImageCrawler 객체 생성
google_crawler = GoogleImageCrawler(storage={'root_dir': './images'})
google_crawler.crawl(keyword='dove', max_num=300)
# Out:
# 2021-01-27 22:42:32,266 - INFO - icrawler.crawler - start crawling...
# 2021-01-27 22:42:32,267 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-01-27 22:42:32,267 - INFO - feeder - thread feeder-001 exit
# 2021-01-27 22:42:32,269 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-01-27 22:42:32,270 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-01-27 22:42:33,683 - INFO - parser - parsing result page https://www.google.com/search?q=pigeon&ijn=0&start=0&tbs=&tbm=isch
# 2021-01-27 22:42:33,713 - INFO - downloader - skip downloading file 000001.jpg
# 2021-01-27 22:42:33,715 - INFO - downloader - skip downloading file 000002.jpg
# 2021-01-27 22:42:33,716 - INFO - downloader - skip downloading file 000003.jpg
# 2021-01-27 22:42:33,717 - INFO - downloader - skip downloading file 000004.jpg
# 2021-01-27 22:42:33,717 - INFO - downloader - skip downloading file 000005.jpg
# ...

# %%
# GoogleImageCrawler 객체 생성
google_crawler = GoogleImageCrawler(storage={'root_dir': './images'})
google_crawler.crawl(keyword='dove bird', max_num=300)
# Out:
# 2021-01-27 22:46:10,196 - INFO - icrawler.crawler - start crawling...
# 2021-01-27 22:46:10,197 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-01-27 22:46:10,197 - INFO - feeder - thread feeder-001 exit
# 2021-01-27 22:46:10,199 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-01-27 22:46:10,200 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-01-27 22:46:11,445 - INFO - parser - parsing result page https://www.google.com/search?q=dove+bird&ijn=0&start=0&tbs=&tbm=isch
# 2021-01-27 22:46:11,795 - INFO - downloader - image #1	https://i.pinimg.com/originals/33/fd/d2/33fdd206ae03ead3a21b3bc7e8a99d50.jpg
# 2021-01-27 22:46:12,144 - INFO - downloader - image #2	http://animal.memozee.com/ArchOLD-7/1188224021.jpg
# 2021-01-27 22:46:33,608 - INFO - downloader - image #3	https://upload.wikimedia.org/wikipedia/commons/f/ff/Treron_vernans_male_-_Kent_Ridge_Park.jpg
# ...
